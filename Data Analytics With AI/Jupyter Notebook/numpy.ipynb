# %%
#NUMPY numerical python

# %%
a=[2,3,5]

# %%
type(a)
# Out:
# list

# %%
#speed #memory efficient #easy to use #lot of tools for maths

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
arr=np.array([[[2,3,4],[8,5,6],[3,4,2]]])

# %%
print(arr)
# Out:
# [[[2 3 4]
#   [8 5 6]
#   [3 4 2]]]

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.size
# Out:
# 9

# %%
arr.shape
# Out:
# (1, 3, 3)

# %%
arr.ndim
# Out:
# 3

# %%
arr1=np.array([4,5,6,7,8])

# %%
print(arr1)
# Out:
# [4 5 6 7 8]

# %%
#mathematical operations + - * / %

# %%
print(arr1 * 10)
# Out:
# [40 50 60 70 80]

# %%
arr3=arr1 + 10

# %%
print(arr3)
# Out:
# [14 15 16 17 18]

# %%
a=np.array([[40, 50 ,60, 70, 80],[23,45,12,45,34]])

# %%
b=a/5

# %%
print(b)
# Out:
# [[ 8.  10.  12.  14.  16. ]
#  [ 4.6  9.   2.4  9.   6.8]]

# %%
print(a)
# Out:
# [[40 50 60 70 80]
#  [23 45 12 45 34]]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
#Aggregate functions in numpy

# %%
a.sum()
# Out:
# np.int64(459)

# %%
a.min()
# Out:
# np.int64(12)

# %%
a.max()
# Out:
# np.int64(80)

# %%
a.mean()
# Out:
# np.float64(45.9)

# %%
a.std()
# Out:
# np.float64(19.521526579650477)

# %%
a.var()
# Out:
# np.float64(381.09000000000003)

# %%
#indexing and slicing

# %%
c=np.array([[[2,3,4,5,6],[5,6,3,2,1],[4,2,1,3,4]]])

# %%
c[2,0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 c[2,0]
#
# IndexError: index 2 is out of bounds for axis 0 with size 1

# %%
c.ndim

# %%
#slicing

# %%
print(c[2:])

# %%
print(c[:3])

# %%
print(c[::-1])

# %%
c[1,2:]

# %%
np.arange(1,10,2)  #start,stop,step

# %%
np.arange(10,0,-2)

# %%
np.zeros((5,3),dtype=int)

# %%
np.eye(4,dtype=int)

# %%
np.ones((2,3),dtype=int)

# %%
np.full((2,3),7)

# %%
np.linspace(0,1,10)

# %%
np.linspace(5,100,10)

# %%
np.random.rand(3,3)   #generate random number of any shape

# %%
np.random.randint(2,80,5)

# %%
e=np.array([10, 42, 25, 23,75, 55])

# %%
print(e)

# %%
e.reshape(2,3)

# %%
c=np.array([[[2,3,4,5,6],[5,6,3,2,1],[4,2,1,3,4]]])

# %%
c.ndim

# %%
d=c.flatten()

# %%
d.ndim

# %%
print(d)

# %%
arr1=np.array([2,3, 4, 5, 6, 5])

# %%
arr4=np.array([23,32, 40, 5, 60, 5])

# %%
arr2=np.array([20,10, 42, 54, 61, 51])

# %%
arr3=np.concatenate((arr1,arr2,arr4))   #concatenate multiple arrays

# %%
print(arr3)

# %%
arr5=np.array([[20,10, 42, 54, 61, 51],[201,101, 421, 541, 611, 51]])

# %%
np.insert(arr5,1,100,axis=0)                          #(array,index,value,axis=0 or 1)  #1 is column

# %%
arr6=np.array([230,32, 40, 5, 60, 50])

# %%
np.append(arr6,100)

# %%
np.delete(arr6,3)

# %%
print(arr6)

# %%
arr6=np.array([230,32, 40, 5, 60, 50])

# %%
np.vstack(arr6)

# %%
np.hstack(arr6)

# %%
np.sort(arr6)

# %%
arr7=np.array([230,32,24, 60, 50, 60, 55])

# %%
np.uniquearr7)

# %%
print(arr7)

# %%
np.where(arr7>50)

# %%
arr7[arr7>50]
# Out:
# array([230,  60,  60,  55])
